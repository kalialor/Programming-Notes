// %% [markdown]
// MongoDB is a collection of documents where the documents are objects
// <br><br><br>
//
//
// ![mongoDb.png](attachment:mongoDb.png)
//
// <br><br>

// %% [markdown]
// <br><br><br>
// <h1>Mongo Atlas</h1>
// <br><br>
// Instead of storing our database locally, we can store it in the cloud. Good for open source projects.
